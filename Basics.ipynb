# %% [markdown]
# # EMPLOYEE EXIT SURVEYS

# %% [markdown]
# The project's purpose is to achieve healthy results from data sets about employe satisfaction. In this project, there are 2 datasets to analyze and those datasets obtained from "The Department of Education, Training and Employment" and "The Technical and Further Education Institute".

# %% [markdown]
# First of all, we are going to start with data cleaning process before data analyzing.

# %% [markdown]
# Let's Start!

# %%
import pandas as pd
import numpy as np

# %%
dete_survey= pd.read_csv("dete_survey.csv")
tafe_survey= pd.read_csv("tafe_survey.csv")

# %%
dete_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
# ID                                     822 non-null int64
# SeparationType                         822 non-null object
# Cease Date                             822 non-null object
# DETE Start Date                        822 non-null object
# Role Start Date                        822 non-null object
# Position                               817 non-null object
# Classification                         455 non-null object
# Region                                 822 non-null object
# Business Unit                          126 non-null object
# Employment Status                      817 non-null object
# Career move to public sector           822 non-null bool
# Career move to private sector          822 non-null bool
# Interpersonal conflicts                822 non-null bool
# Job dissatisfaction                    822 non-null bool
# ...

# %%
dete_survey.head()
# Out:
#    ID                    SeparationType Cease Date DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012            1984
# 1   2  Voluntary Early Retirement (VER)    08/2012      Not Stated
# 2   3  Voluntary Early Retirement (VER)    05/2012            2011
# 3   4         Resignation-Other reasons    05/2012            2005
# 4   5                    Age Retirement    05/2012            1970
#
#   Role Start Date                                      Position  \
# 0            2004                                Public Servant
# 1      Not Stated                                Public Servant
# 2            2011                               Schools Officer
# 3            2006                                       Teacher
# 4            1989  Head of Curriculum/Head of Special Education
#
#   Classification              Region                      Business Unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %%
dete_survey.isnull()
# Out:
#         ID  SeparationType  Cease Date  DETE Start Date  Role Start Date  \
# 0    False           False       False            False            False
# 1    False           False       False            False            False
# 2    False           False       False            False            False
# 3    False           False       False            False            False
# 4    False           False       False            False            False
# 5    False           False       False            False            False
# 6    False           False       False            False            False
# 7    False           False       False            False            False
# 8    False           False       False            False            False
# 9    False           False       False            False            False
# 10   False           False       False            False            False
# 11   False           False       False            False            False
# ...

# %%
dete_survey.isnull().sum()
# Out:
# ID                                       0
# SeparationType                           0
# Cease Date                               0
# DETE Start Date                          0
# Role Start Date                          0
# Position                                 5
# Classification                         367
# Region                                   0
# Business Unit                          696
# Employment Status                        5
# Career move to public sector             0
# Career move to private sector            0
# Interpersonal conflicts                  0
# Job dissatisfaction                      0
# Dissatisfaction with the department      0
# Physical work environment                0
# Lack of recognition                      0
# Lack of job security                     0
# Work location                            0
# Employment conditions                    0
# Maternity/family                         0
# Relocation                               0
# ...

# %%
tafe_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 72 columns):
# Record ID                                                                                                                                                        702 non-null float64
# Institute                                                                                                                                                        702 non-null object
# WorkArea                                                                                                                                                         702 non-null object
# CESSATION YEAR                                                                                                                                                   695 non-null float64
# ...

# %%
tafe_survey.head()
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
# 1  Non-Delivery (corporate)          2010.0                    Retirement
# 2       Delivery (teaching)          2010.0                    Retirement
# 3  Non-Delivery (corporate)          2010.0                   Resignation
# 4       Delivery (teaching)          2010.0                   Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# ...

# %%
tafe_survey.isnull()
# Out:
#      Record ID  Institute  WorkArea  CESSATION YEAR  \
# 0        False      False     False           False
# 1        False      False     False           False
# 2        False      False     False           False
# 3        False      False     False           False
# 4        False      False     False           False
# 5        False      False     False           False
# 6        False      False     False           False
# 7        False      False     False           False
# 8        False      False     False           False
# 9        False      False     False           False
# 10       False      False     False           False
# 11       False      False     False           False
# 12       False      False     False           False
# 13       False      False     False           False
# 14       False      False     False           False
# 15       False      False     False           False
# 16       False      False     False           False
# ...

# %%
tafe_survey.isnull().sum()
# Out:
# Record ID                                                                                                                                                          0
# Institute                                                                                                                                                          0
# WorkArea                                                                                                                                                           0
# CESSATION YEAR                                                                                                                                                     7
# Reason for ceasing employment                                                                                                                                      1
# ...

# %% [markdown]
# In dete_survey dataset, there are 6 column which have null values more than 600.
# Also, the "clasification" column has 367 null values. I think this columns can be eliminated. And I think these columns won't affect the result of analyze subject. There are another columns which have null values less than 100. We can use other methods to make them eligible these null values to evaluate.

# %% [markdown]
# In tafe_survey dataset
# 37 columns have 100-300 null values
# 19 columns have < 100 null values
# 1 column has 589 null values(we can drop this column)

# %%
dete_survey= pd.read_csv("dete_survey.csv",na_values= "Not Stated")

# %%
dete_survey.isnull().sum()
# Out:
# ID                                       0
# SeparationType                           0
# Cease Date                              34
# DETE Start Date                         73
# Role Start Date                         98
# Position                                 5
# Classification                         367
# Region                                 105
# Business Unit                          696
# Employment Status                        5
# Career move to public sector             0
# Career move to private sector            0
# Interpersonal conflicts                  0
# Job dissatisfaction                      0
# Dissatisfaction with the department      0
# Physical work environment                0
# Lack of recognition                      0
# Lack of job security                     0
# Work location                            0
# Employment conditions                    0
# Maternity/family                         0
# Relocation                               0
# ...

# %%
dete_survey_updated=dete_survey.drop(dete_survey.columns[28:49],axis=1)

# %%
tafe_survey_updated= tafe_survey.drop(tafe_survey.columns[17:66], axis=1)

# %% [markdown]
# There were null values in the dete_survey dataset, but the code couldn't see it. Because these null was recorded as " Not Stated". These null values was updated while selection of "Not Stated" values.

# %% [markdown]
# Also the unnecessary columns were dropped from dete_survey dataset and tafe_survey dataset.

# %%
dete_survey_updated.columns= dete_survey_updated.columns.str.replace(" ","_").str.lower().str.strip()

# %%
print( dete_survey_updated.columns)
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity/family', 'relocation', 'study/travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb'],
#       dtype='object')

# %%
mapping= {'Record ID': 'id','CESSATION YEAR': 'cease_date','Reason for ceasing employment': 'separationtype',
'Gender. What is your Gender?': 'gender',
'CurrentAge. Current Age': 'age',
'Employment Type. Employment Type': 'employment_status',
'Classification. Classification': 'position',
'LengthofServiceOverall. Overall Length of Service at Institute (in years)': 'institute_service',
'LengthofServiceCurrent. Length of Service at current workplace (in years)': 'role_service'}
tafe_survey_updated= tafe_survey_updated.rename(mapping, axis=1)

# %%
tafe_survey_updated.head()
# Out:
#              id                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date    separationtype  \
# 0  Non-Delivery (corporate)      2010.0  Contract Expired
# 1  Non-Delivery (corporate)      2010.0        Retirement
# 2       Delivery (teaching)      2010.0        Retirement
# 3  Non-Delivery (corporate)      2010.0       Resignation
# 4       Delivery (teaching)      2010.0       Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
# 3                                                  -
# ...

# %%
dete_survey_updated.head()
# Out:
#    id                    separationtype cease_date  dete_start_date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    role_start_date                                      position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   classification              region                      business_unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %% [markdown]
# In these steps, we tried to provide understandable environment to analysis. We updated the column names' style and provided same column names for same values in two datasets.

# %%
dete_survey_updated["separationtype"].value_counts()
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: separationtype, dtype: int64

# %%
tafe_survey_updated["separationtype"].value_counts()
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: separationtype, dtype: int64

# %%
dete_survey_updated["separationtype"]=dete_survey_updated["separationtype"].str.split("-").str[0]

# %%
dete_resignations= dete_survey_updated[dete_survey_updated["separationtype"]=="Resignation"].copy()

# %%
print(dete_resignations)
# Out:
#       id separationtype cease_date  dete_start_date  role_start_date  \
# 3      4    Resignation    05/2012           2005.0           2006.0
# 5      6    Resignation    05/2012           1994.0           1997.0
# 8      9    Resignation    07/2012           2009.0           2009.0
# 9     10    Resignation       2012           1997.0           2008.0
# 11    12    Resignation       2012           2009.0           2009.0
# 12    13    Resignation       2012           1998.0           1998.0
# 14    15    Resignation       2012           2007.0           2010.0
# 16    17    Resignation       2012              NaN              NaN
# 20    21    Resignation       2012           1982.0           1982.0
# 21    22    Resignation       2012           1980.0           2009.0
# 22    23    Resignation       2012           1997.0           1998.0
# 23    24    Resignation       2012           1973.0           2012.0
# 25    26    Resignation       2012           1995.0           2002.0
# ...

# %%
tafe_resignations=tafe_survey_updated[tafe_survey_updated["separationtype"]== "Resignation"].copy()

# %%
print(tafe_resignations)
# Out:
#                id                              Institute  \
# 3    6.341399e+17            Mount Isa Institute of TAFE
# 4    6.341466e+17  Southern Queensland Institute of TAFE
# 5    6.341475e+17  Southern Queensland Institute of TAFE
# 6    6.341520e+17         Barrier Reef Institute of TAFE
# 7    6.341537e+17  Southern Queensland Institute of TAFE
# 8    6.341579e+17  Southern Queensland Institute of TAFE
# 9    6.341588e+17         Barrier Reef Institute of TAFE
# 10   6.341588e+17         Barrier Reef Institute of TAFE
# 13   6.341725e+17         Barrier Reef Institute of TAFE
# 14   6.341726e+17   Central Queensland Institute of TAFE
# 15   6.341761e+17  Southern Queensland Institute of TAFE
# 16   6.341770e+17       Brisbane North Institute of TAFE
# 17   6.341771e+17       Brisbane North Institute of TAFE
# 18   6.341779e+17       Brisbane North Institute of TAFE
# 19   6.341820e+17      Southbank Institute of Technology
# ...

# %% [markdown]
# We retrieved "Resignation Data" from datasets to use the resignation data in our next analysis easily.

# %%
dete_resignations["cease_date"].value_counts()
# Out:
# 2012       126
# 2013        74
# 01/2014     22
# 12/2013     17
# 06/2013     14
# 09/2013     11
# 11/2013      9
# 07/2013      9
# 10/2013      6
# 08/2013      4
# 05/2012      2
# 05/2013      2
# 2010         1
# 09/2010      1
# 07/2006      1
# 07/2012      1
# Name: cease_date, dtype: int64

# %%
dete_resignations["cease_date"]=dete_resignations["cease_date"].str.split("/").str[-1]

# %%
dete_resignations["cease_date"]=dete_resignations["cease_date"].astype("float")

# %%
dete_resignations["cease_date"].value_counts().sort_index()
# Out:
# 2006.0      1
# 2010.0      2
# 2012.0    129
# 2013.0    146
# 2014.0     22
# Name: cease_date, dtype: int64

# %%
dete_resignations["dete_start_date"].value_counts().sort_index()
# Out:
# 1963.0     1
# 1971.0     1
# 1972.0     1
# 1973.0     1
# 1974.0     2
# 1975.0     1
# 1976.0     2
# 1977.0     1
# 1980.0     5
# 1982.0     1
# 1983.0     2
# 1984.0     1
# 1985.0     3
# 1986.0     3
# 1987.0     1
# 1988.0     4
# 1989.0     4
# 1990.0     5
# 1991.0     4
# 1992.0     6
# 1993.0     5
# 1994.0     6
# 1995.0     4
# 1996.0     6
# 1997.0     5
# 1998.0     6
# 1999.0     8
# 2000.0     9
# 2001.0     3
# 2002.0     6
# 2003.0     6
# 2004.0    14
# 2005.0    15
# 2006.0    13
# 2007.0    21
# 2008.0    22
# 2009.0    13
# 2010.0    17
# 2011.0    24
# 2012.0    21
# 2013.0    10
# Name: dete_start_date, dtype: int64

# %%
tafe_resignations["cease_date"].value_counts().sort_index()
# Out:
# 2009.0      2
# 2010.0     68
# 2011.0    116
# 2012.0     94
# 2013.0     55
# Name: cease_date, dtype: int64

# %% [markdown]
# Most of resignations in dete_survey dataset are in 2013, and most of resignations in tafe survey dataset are in 2011.

# %%
dete_resignations["institute_service"]= dete_resignations["cease_date"]- dete_resignations["dete_start_date"]

# %% [markdown]
# We added a new column to the dete_resignation dataset, and we calculated the service time in this column.

# %%
tafe_resignations['Contributing Factors. Dissatisfaction']
# Out:
# 3                                           -
# 4                                           -
# 5                                           -
# 6                                           -
# 7                                           -
# 8                                           -
# 9                                           -
# 10                                          -
# 13                                          -
# 14     Contributing Factors. Dissatisfaction
# 15                                          -
# 16                                        NaN
# 17                                          -
# 18                                        NaN
# 19                                          -
# 20     Contributing Factors. Dissatisfaction
# 21                                          -
# 22                                          -
# 23                                          -
# 24                                          -
# ...

# %%
tafe_resignations["Contributing Factors. Dissatisfaction"].value_counts()
# Out:
# -                                         277
# Contributing Factors. Dissatisfaction      55
# Name: Contributing Factors. Dissatisfaction, dtype: int64

# %%
tafe_resignations["Contributing Factors. Job Dissatisfaction"].value_counts()
# Out:
# -                      270
# Job Dissatisfaction     62
# Name: Contributing Factors. Job Dissatisfaction, dtype: int64

# %%
def update_vals(x):
    if x=="-":
        return False
    elif pd.isnull(x):
        return np.nan
    else:
        return True

# %%
tafe_resignations["dissatisfied"]= tafe_resignations[['Contributing Factors. Dissatisfaction', 'Contributing Factors. Job Dissatisfaction']].applymap(update_vals).any(1,skipna= False)

# %%
tafe_resignations_up= tafe_resignations.copy()

# %% [markdown]
# We provided easy information about these data set to use them in our examination

# %%
dete_resignations['dissatisfied'] = dete_resignations[['job_dissatisfaction',
       'dissatisfaction_with_the_department', 'physical_work_environment',
       'lack_of_recognition', 'lack_of_job_security', 'work_location',
       'employment_conditions', 'work_life_balance',
       'workload']].any(1, skipna=False)

# %%
dete_resignations_up= dete_resignations.copy()

# %%
dete_resignations_up["institute"]="DETE"
tafe_resignations_up["institute"]="TAFE"

# %%
combined= pd.concat([dete_resignations_up,tafe_resignations_up],ignore_index= True)

# %%
combined_updated= combined.dropna(thresh=500,axis=1).copy()

# %%
combined_updated["institute_service"]. value_counts(dropna=False)
# Out:
# NaN                   88
# Less than 1 year      73
# 1-2                   64
# 3-4                   63
# 5-6                   33
# 11-20                 26
# 5.0                   23
# 1.0                   22
# 7-10                  21
# 0.0                   20
# 3.0                   20
# 6.0                   17
# 4.0                   16
# 2.0                   14
# 9.0                   14
# 7.0                   13
# More than 20 years    10
# 8.0                    8
# 13.0                   8
# 15.0                   7
# 20.0                   7
# 14.0                   6
# 10.0                   6
# 12.0                   6
# 17.0                   6
# 22.0                   6
# 16.0                   5
# 18.0                   5
# 24.0                   4
# 11.0                   4
# 23.0                   4
# 19.0                   3
# 39.0                   3
# 21.0                   3
# 32.0                   3
# 25.0                   2
# 26.0                   2
# ...

# %%
combined_updated["institute_service_up"]=combined_updated["institute_service"].astype("str").str.extract(r"(\d+)")
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   if __name__ == '__main__':

# %%
combined_updated["institute_service_up"]=combined_updated["institute_service_up"].astype("float")

# %%
combined_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651 entries, 0 to 650
# Data columns (total 11 columns):
# age                     596 non-null object
# cease_date              635 non-null float64
# dissatisfied            643 non-null object
# employment_status       597 non-null object
# gender                  592 non-null object
# id                      651 non-null float64
# institute               651 non-null object
# institute_service       563 non-null object
# position                598 non-null object
# separationtype          651 non-null object
# institute_service_up    563 non-null float64
# dtypes: float64(3), object(8)
# memory usage: 56.0+ KB

# %%
combined_updated["institute_service_up"].value_counts()
# Out:
# 1.0     159
# 3.0      83
# 5.0      56
# 7.0      34
# 11.0     30
# 0.0      20
# 20.0     17
# 6.0      17
# 4.0      16
# 9.0      14
# 2.0      14
# 13.0      8
# 8.0       8
# 15.0      7
# 17.0      6
# 10.0      6
# 12.0      6
# 14.0      6
# 22.0      6
# 16.0      5
# 18.0      5
# 24.0      4
# 23.0      4
# 39.0      3
# 19.0      3
# 21.0      3
# 32.0      3
# 28.0      2
# 36.0      2
# 25.0      2
# 30.0      2
# 26.0      2
# 29.0      1
# 38.0      1
# 42.0      1
# 27.0      1
# 41.0      1
# 35.0      1
# 49.0      1
# 34.0      1
# 33.0      1
# 31.0      1
# Name: institute_service_up, dtype: int64

# %%
def transform_service(val):
    if val>= 11:
        return "Veteran"
    elif 7<= val <11:
        return "Established"
    elif 3<= val < 7:
        return "Experienced"
    elif pd.isnull(val):
        return np.nan
    else:
        return "New"

# %%
combined_updated["service_cat"]= combined_updated["institute_service_up"].apply(transform_service)

# %% [markdown]
# So far we created a new column, which categorizes employees according to the amount of years spent in their workplace:
# *New: Less than 3 years at a company
# *Experienced: 3-6 years at a company
# *Established: 7-10 years at a company
# *Veteran: 11 or more years at a company

# %%
combined_updated["dissatisfied"].value_counts(dropna=False)
# Out:
# False    403
# True     240
# NaN        8
# Name: dissatisfied, dtype: int64

# %%
combined_updated["dissatisfied"]= combined_updated["dissatisfied"].fillna(False)

# %%
xx=combined_updated.pivot_table(index="service_cat", values="dissatisfied")

# %%
# %matplotlib inline

# %%
xx.plot(kind="bar")

# %% [markdown]
# You can see the analysis of levels of dissatisfaction from the table above.
